# %% [markdown]
# # Columns Description
#
#
# * **id** - ID yang ditugaskan LC yang unik untuk daftar pinjaman.
# * **member_id** - ID yang ditugaskan LC yang unik untuk anggota peminjam.
# * **loan_amnt** - Jumlah pinjaman yang terdaftar yang diterapkan oleh peminjam. Jika pada suatu titik waktu, departemen kredit mengurangi jumlah pinjaman, maka itu akan tercermin dalam nilai ini.
# * **funded_amnt** -	Jumlah total yang berkomitmen untuk pinjaman itu pada saat itu.
# * **funded_amnt_inv** -	Jumlah total yang dilakukan oleh investor untuk pinjaman itu pada saat itu.
# * **term** - Jumlah pembayaran pinjaman. Nilai dalam beberapa bulan dan dapat berupa 36 atau 60.
# * **int_rate** - Suku bunga pinjaman
# * **installment** - Pembayaran bulanan yang terutang oleh peminjam jika pinjaman berasal.
# * **grade** - LC menugaskan nilai pinjaman
# * **sub_grade** - LC Ditugaskan Subgrade Pinjaman
# * **emp_title**	- Judul pekerjaan yang disediakan oleh peminjam saat mengajukan pinjaman.*
# * **emp_length**	- Panjang pekerjaan dalam beberapa tahun. Nilai yang mungkin adalah antara 0 dan 10 di mana 0 berarti kurang dari satu tahun dan 10 berarti sepuluh tahun atau lebih.
# * **home_ownership**	- Status kepemilikan rumah yang disediakan oleh peminjam selama pendaftaran. Nilai -nilai kami adalah: sewa, sendiri, hipotek, lainnya.
# * **annual_inc**	- Penghasilan tahunan yang dilaporkan sendiri yang disediakan oleh peminjam selama pendaftaran.
# * **verification_status** - --------------------------------------------------------------
# * **issue_d**	- Bulan yang didanai pinjaman
# * **pymnt_plan**	- Menunjukkan jika rencana pembayaran telah diberlakukan untuk pinjaman
# * **url** - URL untuk halaman LC dengan data daftar.
# * **desc** - Deskripsi pinjaman yang disediakan oleh peminjam
# * **purpose**	- Kategori yang disediakan oleh peminjam untuk permintaan pinjaman.
# * **title** - Judul pinjaman yang disediakan oleh peminjam
# * **zip_code** - 3 nomor pertama dari kode pos yang disediakan oleh peminjam dalam aplikasi pinjaman.
# * **addr_state**	- Negara yang disediakan oleh peminjam dalam aplikasi pinjaman
# * **dti**	- Rasio yang dihitung menggunakan total pembayaran utang bulanan peminjam atas total kewajiban utang, tidak termasuk hipotek dan pinjaman LC yang diminta, dibagi dengan pendapatan bulanan peminjam yang dilaporkan sendiri.
# * **delinq_2yrs** - Jumlah 30+ hari insiden kenakalan yang lewat dalam file kredit peminjam selama 2 tahun terakhir
# * **earliest_cr_line** - Bulan jalur kredit yang paling awal dilaporkan peminjam dibuka
# * **inq_last_6mths** - Jumlah pertanyaan dalam 6 bulan terakhir (tidak termasuk pertanyaan otomatis dan hipotek)
# * **mths_since_last_delinq** - Jumlah bulan sejak kenakalan terakhir peminjam.
# * **mths_since_last_record** - Jumlah bulan sejak catatan publik terakhir.
# * **open_acc** - Jumlah jalur kredit terbuka dalam file kredit peminjam.
# * **pub_rec** - Jumlah catatan publik yang menghina
# * **revol_bal** - Total Saldo Revolving Credit
# * **revol_util** - Tingkat pemanfaatan jalur bergulir, atau jumlah kredit yang digunakan peminjam relatif terhadap semua kredit revolving yang tersedia.
# * **total_acc** - Jumlah total jalur kredit saat ini dalam file kredit peminjam
# * **initial_list_status** - Status daftar awal pinjaman. Nilai yang mungkin adalah - w, f
# * **out_prncp** - Kepala sekolah yang tersisa untuk jumlah total yang didanai
# * **out_prncp_inv** - Kepala sekolah yang tersisa untuk sebagian dari jumlah total yang didanai oleh investor
# * **total_pymnt** - Pembayaran diterima hingga saat ini untuk jumlah total yang didanai
# * **total_pymnt_inv** - Pembayaran diterima hingga saat ini untuk sebagian dari jumlah total yang didanai oleh investor
# * **total_rec_int** - Bunga diterima hingga saat ini
# * **total_rec_late_fee** - Biaya keterlambatan yang diterima hingga saat ini
# * **total_rec_prncp** - Kepala sekolah diterima hingga saat ini
# * **recoveries** - Posting biaya pemulihan kotor
# * **collection_recovery_fee** - Biaya pengumpulan biaya penagihan
# * **last_pymnt_d** - Bulan lalu pembayaran diterima
# * **last_pymnt_amnt** - Jumlah total pembayaran terakhir yang diterima
# * **next_pymnt_d** - Tanggal Pembayaran Terjadwal Berikutnya
# * **last_credit_pull_d** - Bulan terbaru LC menarik kredit untuk pinjaman ini
# * **collections_12_mths_ex_med** - Jumlah koleksi dalam 12 bulan tidak termasuk koleksi medis
# * **mths_since_last_major_derog** - Bulan sejak peringkat 90 hari atau lebih buruk terakhir
# * **policy_code**	 - "Policy_code yang tersedia untuk umum = 1 Produk Baru Tidak Tersedia Umum Kebijakan_Code = 2"
# * **application_type** - Menunjukkan apakah pinjaman adalah aplikasi individu atau aplikasi bersama dengan dua peminjam bersama
# * **annual_inc_joint** - Penghasilan tahunan yang dilaporkan sendiri gabungan yang disediakan oleh co-peminjam selama pendaftaran
# * **dti_joint** - Rasio yang dihitung menggunakan total pembayaran bulanan peminjam bersama atas total kewajiban utang, tidak termasuk hipotek dan pinjaman LC yang diminta, dibagi oleh pendapatan bulanan yang dilaporkan sendiri oleh co-peminjam yang dilaporkan sendiri
# * **verification_status_joint** - ------------------------------------------------------------------------
# * **acc_now_delinq** - Jumlah akun di mana peminjam sekarang nakal.
# * **tot_coll_amt** - Total jumlah pengumpulan yang pernah ada
# * **tot_cur_bal** - Total Saldo Saat Ini dari Semua Akun
# * **open_acc_6m** - Jumlah perdagangan terbuka dalam 6 bulan terakhir
# * **open_il_6m** - Jumlah perdagangan angsuran aktif saat ini
# * **open_il_12m** - Jumlah akun angsuran yang dibuka dalam 12 bulan terakhir
# * **open_il_24m** - Jumlah akun angsuran yang dibuka dalam 24 bulan terakhir
# * **mths_since_rcnt_il** - Bulan sejak akun angsuran terbaru dibuka
# * **total_bal_il** - Total saldo saat ini dari semua akun angsuran
# * **il_util** - Rasio total saldo saat ini dengan batas kredit/kredit tinggi pada semua instal acct
# * **open_rv_12m** - Jumlah perdagangan revolving dibuka dalam 12 bulan terakhir
# * **open_rv_24m** - Jumlah perdagangan revolving dibuka dalam 24 bulan terakhir
# * **max_bal_bc** - Saldo arus maksimum terutang pada semua akun bergulir
# * **all_util** - Saldo ke batas kredit untuk semua perdagangan
# * **total_rev_hi_lim** - Total Batas Kredit/Kredit Tinggi Revolving
# * **inq_fi** - Jumlah pertanyaan keuangan pribadi
# * **total_cu_tl** - Jumlah Perdagangan Keuangan
# * **inq_last_12m** - Jumlah pertanyaan kredit dalam 12 bulan terakhir
# * **bad_loan** - data orang tepat membayar full atau tidak

# %% [markdown]
# # Importing Dependencies

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 99)

# %% [markdown]
# # Load the Dataset

# %%
missing_values = ["N/a","na","NaN","nan",np.nan]

df = pd.read_csv('loan_data_2007_2014.csv', na_values=missing_values)
# Out:
# C:\Users\Sandie\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (20) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# mendefinisikan nilai dari parameter na_values karena nilai N/A mungkin saja dituliskan dengan cara yang berbeda-beda didalam dataset

# %%
df.head(10)
# Out:
#    Unnamed: 0       id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 0           0  1077501    1296599       5000         5000           4975.0
# 1           1  1077430    1314167       2500         2500           2500.0
# 2           2  1077175    1313524       2400         2400           2400.0
# 3           3  1076863    1277178      10000        10000          10000.0
# 4           4  1075358    1311748       3000         3000           3000.0
# 5           5  1075269    1311441       5000         5000           5000.0
# 6           6  1069639    1304742       7000         7000           7000.0
# 7           7  1072053    1288686       3000         3000           3000.0
# 8           8  1071795    1306957       5600         5600           5600.0
# 9           9  1071570    1306721       5375         5375           5350.0
#
#          term  int_rate  installment grade sub_grade  \
# 0   36 months     10.65       162.87     B        B2
# ...

# %%
df.shape
# Out:
# (466285, 75)

# %%
df.drop('Unnamed: 0', axis='columns', inplace=True)
df.shape
# Out:
# (466285, 74)

# %% [markdown]
# menghapus kolom 'Unnamed: 0'

# %% [markdown]
# kolom 'Unnamed: 0' berhasil dihapus

# %% [markdown]
# # Cek Deskripsi Statistik Data

# %%
df.shape
# Out:
# (466285, 74)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 466285 entries, 0 to 466284
# Data columns (total 74 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   id                           466285 non-null  int64
#  1   member_id                    466285 non-null  int64
#  2   loan_amnt                    466285 non-null  int64
#  3   funded_amnt                  466285 non-null  int64
#  4   funded_amnt_inv              466285 non-null  float64
#  5   term                         466285 non-null  object
#  6   int_rate                     466285 non-null  float64
#  7   installment                  466285 non-null  float64
#  8   grade                        466285 non-null  object
#  9   sub_grade                    466285 non-null  object
#  10  emp_title                    438693 non-null  object
#  11  emp_length                   445277 non-null  object
# ...

# %%
df.describe()
# Out:
#                  id     member_id      loan_amnt    funded_amnt  \
# count  4.662850e+05  4.662850e+05  466285.000000  466285.000000
# mean   1.307973e+07  1.459766e+07   14317.277577   14291.801044
# std    1.089371e+07  1.168237e+07    8286.509164    8274.371300
# min    5.473400e+04  7.047300e+04     500.000000     500.000000
# 25%    3.639987e+06  4.379705e+06    8000.000000    8000.000000
# 50%    1.010790e+07  1.194108e+07   12000.000000   12000.000000
# 75%    2.073121e+07  2.300154e+07   20000.000000   20000.000000
# max    3.809811e+07  4.086083e+07   35000.000000   35000.000000
#
#        funded_amnt_inv       int_rate    installment    annual_inc  \
# count    466285.000000  466285.000000  466285.000000  4.662810e+05
# mean      14222.329888      13.829236     432.061201  7.327738e+04
# std        8297.637788       4.357587     243.485550  5.496357e+04
# min           0.000000       5.420000      15.670000  1.896000e+03
# ...

# %%
nunique = pd.DataFrame(df.nunique())
nunique.columns = ['number of unique values']

# %%
nunique
# Out:
#                              number of unique values
# id                                            466285
# member_id                                     466285
# loan_amnt                                       1352
# funded_amnt                                     1354
# funded_amnt_inv                                 9854
# term                                               2
# int_rate                                         506
# installment                                    55622
# grade                                              7
# sub_grade                                         35
# emp_title                                     205474
# emp_length                                        11
# home_ownership                                     6
# annual_inc                                     31901
# verification_status                                3
# issue_d                                           91
# loan_status                                        9
# ...

# %%
freq = df.dtypes.value_counts()
percentages = np.around((df.dtypes.value_counts(normalize="True")*100), 2)
data = {
    "frequencies":freq,
    "percentages":percentages
}

# %%
pd.DataFrame(data)
# Out:
#          frequencies  percentages
# float64           46        62.16
# object            22        29.73
# int64              6         8.11

# %%
df.dtypes.value_counts().plot(kind="pie", title="Proportion of each data type")
# Out:
# <AxesSubplot:title={'center':'Proportion of each data type'}, ylabel='None'>

# %% [markdown]
# # Buat Kolom Target

# %%
df['bad_loan'] = np.where(df.loc[:, 'loan_status'].isin(['Charged Off', 'Default', 'Late (31-120 days)',
                                        'Does not meet the credit policy. Status:Charged Off']), 0, 1)

# %%
df['bad_loan'].describe()
# Out:
# count    466285.000000
# mean          0.890693
# std           0.312024
# min           0.000000
# 25%           1.000000
# 50%           1.000000
# 75%           1.000000
# max           1.000000
# Name: bad_loan, dtype: float64

# %%
df['bad_loan'].head(5)
# Out:
# 0    1
# 1    0
# 2    1
# 3    1
# 4    1
# Name: bad_loan, dtype: int32

# %% [markdown]
# kolom target sudah berhasil ditambahkan

# %% [markdown]
# # Memeriksa Struktur Fitur Kategorikal

# %%
df.describe(include="object")
# Out:
#               term   grade sub_grade emp_title emp_length home_ownership  \
# count       466285  466285    466285    438693     445277         466285
# unique           2       7        35    205474         11              6
# top      36 months       B        B3   Teacher  10+ years       MORTGAGE
# freq        337953  136929     31686      5399     150049         235875
#
#        verification_status issue_d loan_status pymnt_plan  \
# count               466285  466285      466285     466285
# unique                   3      91           9          2
# top               Verified  Oct-14     Current          n
# freq                168055   38782      224226     466276
#
#                                                       url    desc  \
# count                                              466285  125983
# unique                                             466285  124436
# top     https://www.lendingclub.com/browse/loanDetail....
# ...

# %% [markdown]
# terdapat beberapa fitur yang memiliki nilai berupa tanggal, agar dapat diproses lebih lanjut tipe nya akan dirubah menjadi "datetime", dan fitur term nilainya berupa berapa bulan ...... nilai pada fitur ini dirasa lebih cocok diubah menjadi angka, oleh karena itu, fitur term akan diubah menjadi beritpe numerik

# %%
df.select_dtypes(include="object").sample(5)
# Out:
#               term grade sub_grade                          emp_title  \
# 390178   36 months     D        D1                    Project Manager
# 324126   36 months     A        A4                     Vice President
# 441200   36 months     C        C1                              Sales
# 74754    60 months     C        C1  ASSISTIVE TECHNOLOGY PROFESSIONAL
# 75098    60 months     E        E4            mental health associate
#
#        emp_length home_ownership verification_status issue_d loan_status  \
# 390178    2 years       MORTGAGE     Source Verified  May-14     Current
# 324126  10+ years           RENT     Source Verified  Aug-14     Current
# 441200    7 years           RENT        Not Verified  Feb-14     Current
# 74754   10+ years       MORTGAGE     Source Verified  Oct-13     Current
# 75098     4 years           RENT     Source Verified  Oct-13     Current
#
#        pymnt_plan                                                url  \
# ...

# %%
# For each numerical feature compute number of unique entries
unique_values = df.select_dtypes(include="object").nunique().sort_values()

# Plot information with y-axis in log-scale
unique_values.plot.bar(logy=True, figsize=(15, 4), title="Unique values per feature");

# %% [markdown]
# # Memeriksa Struktur Fitur Numerik

# %%
df.select_dtypes(include="number").describe()
# Out:
#                  id     member_id      loan_amnt    funded_amnt  \
# count  4.662850e+05  4.662850e+05  466285.000000  466285.000000
# mean   1.307973e+07  1.459766e+07   14317.277577   14291.801044
# std    1.089371e+07  1.168237e+07    8286.509164    8274.371300
# min    5.473400e+04  7.047300e+04     500.000000     500.000000
# 25%    3.639987e+06  4.379705e+06    8000.000000    8000.000000
# 50%    1.010790e+07  1.194108e+07   12000.000000   12000.000000
# 75%    2.073121e+07  2.300154e+07   20000.000000   20000.000000
# max    3.809811e+07  4.086083e+07   35000.000000   35000.000000
#
#        funded_amnt_inv       int_rate    installment    annual_inc  \
# count    466285.000000  466285.000000  466285.000000  4.662810e+05
# mean      14222.329888      13.829236     432.061201  7.327738e+04
# std        8297.637788       4.357587     243.485550  5.496357e+04
# min           0.000000       5.420000      15.670000  1.896000e+03
# ...

# %%
df.select_dtypes(include="number").sample(5)
# Out:
#               id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 68047    8561283   10312666       4975         4975           4975.0
# 179862   2286099    2708348      11100        11100          11025.0
# 170561   3195548    3928322      22000        22000          21925.0
# 299045  28772884   31286027      11200        11200          11200.0
# 90615    7051011    8712840      30000        30000          30000.0
#
#         int_rate  installment  annual_inc    dti  delinq_2yrs  inq_last_6mths  \
# 68047       8.90       157.98     47000.0   9.42          0.0             1.0
# 179862     17.27       397.24     39000.0  24.22          1.0             3.0
# 170561     12.12       731.98     50112.0  23.73          0.0             0.0
# 299045     18.24       285.88     57000.0   9.20          0.0             0.0
# 90615      19.20       781.53     75000.0  24.70          1.0             0.0
#
#         mths_since_last_delinq  mths_since_last_record  open_acc  pub_rec  \
# ...

# %%
# For each numerical feature compute number of unique entries
unique_values = df.select_dtypes(include="number").nunique().sort_values()

# Plot information with y-axis in log-scale
unique_values.plot.bar(logy=True, figsize=(15, 4), title="Unique values per feature");

# %% [markdown]
# At the end of this first investigation, we should have a better understanding of the general structure of our dataset. Number of samples and features, what kind of data type each feature has, and how many of them are binary, ordinal, categorical or continuous. For an alternative way to get such kind of information you could also use df_X.info() or df_X.describe().

# %% [markdown]
# # Konversi Beberapa Fitur dengan nilai berupa date ke tipe datetime

# %% [markdown]
# masih terdapat beberapa kolom yang nilainya berupa data namun tipe kolomnya masih berupa 'object', agar bisa diproses lebih lanjut kolom-kolom tersebut akan diubah menjadi tipe datetime

# %%
datetime_features = ['earliest_cr_line','last_pymnt_d','next_pymnt_d']

# %%
df[datetime_features].head(5)
# Out:
#   earliest_cr_line last_pymnt_d next_pymnt_d
# 0           Jan-85       Jan-15          NaN
# 1           Apr-99       Apr-13          NaN
# 2           Nov-01       Jun-14          NaN
# 3           Feb-96       Jan-15          NaN
# 4           Jan-96       Jan-16       Feb-16

# %%
df[datetime_features].dtypes
# Out:
# earliest_cr_line    object
# last_pymnt_d        object
# next_pymnt_d        object
# dtype: object

# %%
for col in datetime_features:
    df[col] = pd.to_datetime(df[col], format='%b-%y')

# %%
df[datetime_features].dtypes
# Out:
# earliest_cr_line    datetime64[ns]
# last_pymnt_d        datetime64[ns]
# next_pymnt_d        datetime64[ns]
# dtype: object

# %%
df[datetime_features].head(5)
# Out:
#   earliest_cr_line last_pymnt_d next_pymnt_d
# 0       1985-01-01   2015-01-01          NaT
# 1       1999-04-01   2013-04-01          NaT
# 2       2001-11-01   2014-06-01          NaT
# 3       1996-02-01   2015-01-01          NaT
# 4       1996-01-01   2016-01-01   2016-02-01

# %% [markdown]
# Terlihat pada output code cell diatas masih terdapat nilai NaN, sebelum menghandle nilai NaN tersebut semua fitur kolom tipe datetime akan diubah menjadi jarak dari tanggal pada fitur tersebut ke tanggal referensi dalam bulan

# %% [markdown]
# # Mengubah Fitur-Fitur Bertipe Datetime Menjadi Numerik

# %% [markdown]
# Memodifikasi fitur-fitur bertipe date dari format bulan-tahun menjadi perhitungan berapa lama waktu berlalu sejak waktu tersebut. Untuk melakukan hal ini, umumnya digunakan reference date = hari ini. Namun, karena dataset ini merupakan dataset tahun 2007-2014, maka akan lebih relevan jika menggunakan reference date di sekitar tahun 2017. Dalam contoh ini, saya menggunakan tanggal 2017-12-01 sebagai reference date.

# %%
new_cols = [(col+'_month') for col in datetime_features]
new_cols
# Out:
# ['earliest_cr_line_month', 'last_pymnt_d_month', 'next_pymnt_d_month']

# %%
df.shape
# Out:
# (466285, 75)

# %%
for col in datetime_features:
    df[col+'_month'] = round(
        pd.to_numeric((pd.to_datetime('2017-12-01') - df[col]) / np.timedelta64(1, 'M'))
    )
df.shape
# Out:
# (466285, 78)

# %%
df[new_cols].head(5)
# Out:
#    earliest_cr_line_month  last_pymnt_d_month  next_pymnt_d_month
# 0                   395.0                35.0                 NaN
# 1                   224.0                56.0                 NaN
# 2                   193.0                42.0                 NaN
# 3                   262.0                35.0                 NaN
# 4                   263.0                23.0                22.0

# %% [markdown]
# terlihat masih terdapat nilai NaN pada kolom next_pymnt_d_month

# %%
df.loc[df['next_pymnt_d_month'] != df['next_pymnt_d_month'],['next_pymnt_d_month']]
# Out:
#         next_pymnt_d_month
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 5                      NaN
# ...                    ...
# 466276                 NaN
# 466277                 NaN
# 466278                 NaN
# 466281                 NaN
# 466283                 NaN
#
# [227214 rows x 1 columns]

# %% [markdown]
# nilai NaN akan direplace dengan nilai rata-rata dari kolom next_pymnt_d_month

# %%
df['next_pymnt_d_month'] = np.where(
    df['next_pymnt_d_month'] != df['next_pymnt_d_month'],
    df['next_pymnt_d_month'].mean(), 
    df['next_pymnt_d_month']
)

df[new_cols].head(5)
# Out:
#    earliest_cr_line_month  last_pymnt_d_month  next_pymnt_d_month
# 0                   395.0                35.0           22.738136
# 1                   224.0                56.0           22.738136
# 2                   193.0                42.0           22.738136
# 3                   262.0                35.0           22.738136
# 4                   263.0                23.0           22.000000

# %%
df[new_cols].describe()
# Out:
#        earliest_cr_line_month  last_pymnt_d_month  next_pymnt_d_month
# count           466256.000000       465909.000000       466285.000000
# mean               239.482430           31.294369           22.738136
# std                 93.974829           12.809898            4.355169
# min               -612.000000           23.000000           21.000000
# 25%                183.000000           23.000000           22.000000
# 50%                225.000000           24.000000           22.738136
# 75%                285.000000           35.000000           22.738136
# max                587.000000          120.000000          120.000000

# %% [markdown]
# pada kolom 'earliest_cr_line_month' nilai min bernilai minus yang mana hal ini tidak masuk akal, periksa penyebab dari munculnya nilai minus tersebut

# %%
df.loc[
    df['earliest_cr_line_month'] < 0, 
    np.concatenate((new_cols,datetime_features))
]
# Out:
#         earliest_cr_line_month  last_pymnt_d_month  next_pymnt_d_month  \
# 1580                    -537.0                51.0           22.738136
# 1770                    -609.0                70.0           22.738136
# 2799                    -561.0                24.0           22.000000
# 3282                    -597.0                36.0           22.738136
# 3359                    -566.0                36.0           22.738136
# ...                        ...                 ...                 ...
# 464003                  -601.0                23.0           22.000000
# 464260                  -583.0                38.0           22.738136
# 465100                  -598.0                23.0           22.000000
# 465500                  -597.0                29.0           22.738136
# 465655                  -457.0                44.0           22.738136
#
#        earliest_cr_line last_pymnt_d next_pymnt_d
# 1580         2062-09-01   2013-09-01          NaT
# ...

# %% [markdown]
# terdapat 1169 yang memiliki nilai minus pada kolom 'earliest_cr_line_month', ternyata hal ini disebabkan oleh nilai tahun yang tidak wajar pada kolom 'earliest_cr_line' yaitu tahun yang jauh melewati tahun yang dijadikan reference yaitu 2017. Ini terjadi karena program mengkonversi 2 digit terakhir seperti 64 yang seharusnya berarti 1964 menjadi 2064.

# %% [markdown]
# Selanjutnya kita akan meng-handle nilai yang tidak wajar ini dengan merubah 2 digit pertama tahunya menjadi '19' bukan '20'

# %%
def handle_unrealistic_year(datetime_obj):
    temp = ''
    new_year = 0
    year = datetime_obj.year
    if  year > 2017:
        temp = str(year)[2:]
        new_year = int('19'+temp)
        datetime_obj = datetime_obj.replace(year=new_year)
    return datetime_obj

# %%
df.loc[df['earliest_cr_line'] > '2017-12-01',['earliest_cr_line']].head(5)
# Out:
#      earliest_cr_line
# 1580       2062-09-01
# 1770       2068-09-01
# 2799       2064-09-01
# 3282       2067-09-01
# 3359       2065-02-01

# %%
df.loc[df['earliest_cr_line'].dt.year > 2017 ,['earliest_cr_line']].head(5)
# Out:
#      earliest_cr_line
# 1580       2062-09-01
# 1770       2068-09-01
# 2799       2064-09-01
# 3282       2067-09-01
# 3359       2065-02-01

# %%
df['earliest_cr_line'] = df['earliest_cr_line'].map(handle_unrealistic_year)

# %%
df.loc[df['earliest_cr_line'] > '2017-12-01',['earliest_cr_line']]
# Out:
# Empty DataFrame
# Columns: [earliest_cr_line]
# Index: []

# %%
df['earliest_cr_line'].head(5)
# Out:
# 0   1985-01-01
# 1   1999-04-01
# 2   2001-11-01
# 3   1996-02-01
# 4   1996-01-01
# Name: earliest_cr_line, dtype: datetime64[ns]

# %% [markdown]
# tahun yang tidak wajar berhasil di handle

# %% [markdown]
# buat kembali 'earliest_cr_line_month' dengan menggunakan nilai dari kolom 'earliest_cr_line' yang sudah diperbaiki

# %%
df['earliest_cr_line_month'] = round(
        pd.to_numeric((pd.to_datetime('2017-12-01') - df['earliest_cr_line']) / np.timedelta64(1, 'M'))
    )

# %%
df[new_cols].describe()
# Out:
#        earliest_cr_line_month  last_pymnt_d_month  next_pymnt_d_month
# count           466256.000000       465909.000000       466285.000000
# mean               242.491078           31.294369           22.738136
# std                 86.928944           12.809898            4.355169
# min                 73.000000           23.000000           21.000000
# 25%                184.000000           23.000000           22.000000
# 50%                226.000000           24.000000           22.738136
# 75%                285.000000           35.000000           22.738136
# max                887.000000          120.000000          120.000000

# %% [markdown]
# nilai minus berhasil dihilangkan dari kolom 'earliest_cr_line_month'

# %%
np.concatenate((new_cols, datetime_features))
# Out:
# array(['earliest_cr_line_month', 'last_pymnt_d_month',
#        'next_pymnt_d_month', 'earliest_cr_line', 'last_pymnt_d',
#        'next_pymnt_d'], dtype='<U22')

# %%
df.loc[df['earliest_cr_line_month'] > 600, np.concatenate((new_cols, datetime_features))]
# Out:
#         earliest_cr_line_month  last_pymnt_d_month  next_pymnt_d_month  \
# 1580                     663.0                51.0           22.738136
# 2799                     639.0                24.0           22.000000
# 3282                     603.0                36.0           22.738136
# 3359                     634.0                36.0           22.738136
# 3413                     606.0                60.0           22.738136
# ...                        ...                 ...                 ...
# 463887                   643.0                23.0           22.000000
# 464260                   617.0                38.0           22.738136
# 465100                   602.0                23.0           22.000000
# 465500                   603.0                29.0           22.738136
# 465655                   743.0                44.0           22.738136
#
#        earliest_cr_line last_pymnt_d next_pymnt_d
# 1580         1962-09-01   2013-09-01          NaT
# ...

# %% [markdown]
# nilai min pada kolom 'earliest_cr_line_month' sudah bukan minus lagi

# %% [markdown]
# # Cek Persentase Unique Values pada Kolom yang baru dibuat

# %% [markdown]
# selanjutna kita akan mengecek persentase kemunculan unique values pada kolom yang baru dibuat yaitu kolom hasil konversi dari kolom datetime sebelumnya

# %%
print(f'Unique Values Percentage of "{datetime_features[0]}_month"')
un = pd.DataFrame(((df[datetime_features[0]+'_month'].value_counts(normalize=True)*100)).head(10))
un.columns = ['Unique Values Percentage']
un
# Out:
# Unique Values Percentage of "earliest_cr_line_month"
#        Unique Values Percentage
# 206.0                  0.787979
# 208.0                  0.771465
# 196.0                  0.741009
# 218.0                  0.730500
# 194.0                  0.713985
# 217.0                  0.712699
# 205.0                  0.700688
# 207.0                  0.698329
# 219.0                  0.671305
# 220.0                  0.670447

# %%
print(f'Unique Values Percentage of "{datetime_features[0]}_month"')
un.plot.bar(figsize=(15, 4), title="Unique values per feature");
# Out:
# Unique Values Percentage of "earliest_cr_line_month"

# %% [markdown]
# terlihat disni dari 10 unique values yang paling sering muncul, persentasenya cukup merata

# %%
print(f'Unique Values Percentage of "{datetime_features[1]}_month"')
un = pd.DataFrame((df[datetime_features[1]+'_month'].value_counts(normalize=True)*100).head(10))
un.columns = ['Unique Values Percentage']
un
# Out:
# Unique Values Percentage of "last_pymnt_d_month"
#       Unique Values Percentage
# 23.0                 38.552593
# 24.0                 13.307320
# 29.0                  2.511864
# 26.0                  2.414205
# 27.0                  2.190127
# 33.0                  2.165015
# 30.0                  2.163083
# 32.0                  2.157288
# 28.0                  2.133249
# 31.0                  2.064352

# %%
print(f'Unique Values Percentage of "{datetime_features[0]}_month"')
un.plot.bar(figsize=(15, 4), title="Unique values per feature");
# Out:
# Unique Values Percentage of "earliest_cr_line_month"

# %% [markdown]
# pada kolom ini, kemunculan nilai 23.0 sangatlah tinggi yakni hampir mencapai setengah dari data yang ada pada kolom tersebut

# %%
print(f'Unique Values Percentage of "{datetime_features[2]}_month"')
un = pd.DataFrame((df[datetime_features[2]+'_month'].value_counts(normalize=True)*100).head(10))
un.columns = ['Unique Values Percentage']
un
# Out:
# Unique Values Percentage of "next_pymnt_d_month"
#            Unique Values Percentage
# 22.738136                 48.728567
# 22.000000                 44.692195
# 23.000000                  5.988183
# 81.000000                  0.022947
# 80.000000                  0.021661
# 82.000000                  0.019516
# 83.000000                  0.016942
# 79.000000                  0.016514
# 84.000000                  0.015227
# 78.000000                  0.014154

# %%
print(f'Unique Values Percentage of "{datetime_features[2]}_month"')
un.plot.bar(figsize=(15, 4), title="Unique values per feature");
# Out:
# Unique Values Percentage of "next_pymnt_d_month"

# %% [markdown]
# pada kolom ini, kemunculan nilai 0 sangatlah tinggi yakni hampir mencapai setengah dari data yang ada pada kolom tersebut, oleh karena itu kita akan menghapus kolom ini karena hampir sebagian besar nilanya merupakan 0, selain itu kemunculan nilai 22.0 juga cukup tinggi dan persentasenya berada diangka sekitar 40%an

# %% [markdown]
# # Drop Kolom next_pymnt_d_month

# %% [markdown]
# oleh karena persentase kemunculan nilai 0 pada fitur 'next_pymnt_d_new' yaitu mencapai 48 persen yang mana cukup tinggi, maka fitur tersebut akan di drop

# %%
df.shape
# Out:
# (466285, 78)

# %%
df.drop('next_pymnt_d_month', axis=1, inplace=True)

# %%
df.shape
# Out:
# (466285, 77)

# %% [markdown]
# karena kolom ditatas memiliki nilai 0 dengan presentasi yang sangat tinggi (48 persen), maka fitur tersebut akan di drop

# %% [markdown]
# # Hapus Kolom Bertipe Datetime

# %% [markdown]
# selanjutnya kolom bertipe datetime akan kita hapus karena sudah di konversi menjadi kolom baru

# %%
df.shape
# Out:
# (466285, 77)

# %%
df.drop(datetime_features, axis=1, inplace=True)

# %%
df.shape
# Out:
# (466285, 74)

# %% [markdown]
# # Mengubah Fitur 'term' menjadi tipe numerik

# %%
df['term'].nunique()
# Out:
# 2

# %%
df['term'].unique()
# Out:
# array([' 36 months', ' 60 months'], dtype=object)

# %%
df['term_int'] = df['term'].str.replace(' months', '')
df['term_int'] = df['term_int'].str.strip()

# %%
df['term_int'] = df['term_int'].astype(int)

# %%
df.shape
# Out:
# (466285, 74)

# %%
df.drop('term', axis=1, inplace=True)
df.shape
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13396/2210388500.py in <module>
# ----> 1 df.drop('term', axis=1, inplace=True)
#       2 df.shape
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
df['term_int'].unique()
# Out:
# array([36., 60.])

# %% [markdown]
# # Cek Banyaknya Nilai Unik pada Kolom Bertipe Kategorikal

# %%
categorical_columns = df.select_dtypes(include="object").columns.tolist()
columns_with_high_cardinality = [col for col in categorical_columns if df[col].nunique() > 30]
columns_with_high_cardinality
# Out:
# ['sub_grade',
#  'emp_title',
#  'issue_d',
#  'url',
#  'desc',
#  'title',
#  'zip_code',
#  'addr_state',
#  'last_credit_pull_d']

# %%
print(f'terdapat {len(columns_with_high_cardinality)} kolom bertipe kategorikal yang memiliki kardinalitas tinggai (jumlah kategorinya lebih dari 30 kategori)')
# Out:
# terdapat 9 kolom bertipe kategorikal yang memiliki kardinalitas tinggai (jumlah kategorinya lebih dari 30 kategori)

# %%
high_card = pd.DataFrame(df[columns_with_high_cardinality].nunique().sort_values(ascending=False))
high_card.columns = ['Number of unique values']
high_card
# Out:
#                     Number of unique values
# url                                  466285
# emp_title                            205474
# desc                                 124436
# title                                 63099
# zip_code                                888
# last_credit_pull_d                      103
# issue_d                                  91
# addr_state                               50
# sub_grade                                35

# %%
un = df.select_dtypes(include="object").nunique().sort_values()
un.plot.bar(logy=True, figsize=(15, 4), title="Unique values per feature");

# %% [markdown]
# pada bar chart diatas, terlihat kesembilan kolom yang sudah disebutkan sebelumnya memiliki kardinalitas yang cukup tingga

# %% [markdown]
# # Menghapus Kolom Bertipe Kategorikal yang memilik Kardinalitas Tinggi

# %%
df.shape
# Out:
# (466285, 74)

# %%
df.drop(columns_with_high_cardinality, axis='columns', inplace=True)
df.shape
# Out:
# (466285, 65)

# %%
df.select_dtypes(include="object").nunique()
# Out:
# grade                   7
# emp_length             11
# home_ownership          6
# verification_status     3
# loan_status             9
# pymnt_plan              2
# purpose                14
# initial_list_status     2
# application_type        1
# dtype: int64

# %% [markdown]
# # Menghapus Kolom yang Hanya Memiliki 1 Nilai Unik

# %% [markdown]
# kolom 'policy_code' dan 'application_type' hanya memilik 1 nilai unik dan hal tersebut tidak akan memberikan informasi dan dampak lebih pada tahap analisi data maupun modelling. Oleh karena itu, sebaiknya 2 kolom tersebut di hapus saja

# %%
df.shape
# Out:
# (466285, 65)

# %%
df.drop(['policy_code', 'application_type'], axis='columns', inplace=True)
df.shape
# Out:
# (466285, 63)

# %% [markdown]
# # Cek Kolom yang Nilainya 0 semua

# %%
columns_with_zero_value = [col for col in df.columns if df[col].nunique() == 0]

# %%
for col in columns_with_zero_value:
    print(f'{col} : {df[col].nunique()}')
# Out:
# annual_inc_joint : 0
# dti_joint : 0
# verification_status_joint : 0
# open_acc_6m : 0
# open_il_6m : 0
# open_il_12m : 0
# open_il_24m : 0
# mths_since_rcnt_il : 0
# total_bal_il : 0
# il_util : 0
# open_rv_12m : 0
# open_rv_24m : 0
# max_bal_bc : 0
# all_util : 0
# inq_fi : 0
# total_cu_tl : 0
# inq_last_12m : 0

# %%
print(f'terdapat {len(columns_with_zero_value)} kolom yang seluruh nilainya adalah 0')
# Out:
# terdapat 17 kolom yang seluruh nilainya adalah 0

# %% [markdown]
# # Menghapus Kolom yang Nilainya 0 semua

# %%
df.shape
# Out:
# (466285, 63)

# %%
df.drop(columns_with_zero_value, axis='columns', inplace=True)
df.shape
# Out:
# (466285, 46)

# %% [markdown]
# # To-Do

# %% [markdown]
# Sebelum memulai modelling, investigasi yang akan dilakukan pada dataset ini yaitu diantaranya:
#    1. Structure Investigation : mengeksplor shape dari dataset dan juga tipe dari masing-masing fitur
#    2. Quality Investigation : memeriksa kualitas dataset dengan memeriksa adanya duplicate data, missing values, ataupun nilai yang tidak diinginkan lainya
#    3. Content Investigation : melakukan EDA untuk mengekslorasi fitur-fitur lebih lanjut dan menemukan korelasi antar fitur

# %% [markdown]
# # Menghapus Kolom yang Tidak Relevan

# %%
irrelevant_columns = ['id','member_id']

# %% [markdown]
# kolom 'id' dan 'member_id' dapat di drop karena hanya merupakan kode unik untuk masing masing pengguna dan tidak akan menambahkan informasi tambahan apapun pada tahap modelling

# %%
df.shape
# Out:
# (466285, 46)

# %%
df.drop(irrelevant_columns, axis='columns', inplace=True)
df.shape
# Out:
# (466285, 44)

# %% [markdown]
# # Check for Missing Values Per Sample

# %%
plt.figure(figsize=(10, 8))
plt.imshow(df.isna(), aspect="auto", interpolation="nearest", cmap="gray")
plt.xlabel("Column Number")
plt.ylabel("Sample Number");

# %% [markdown]
# From both of these plots we can see that the dataset has a huge whole, caused by some samples where more than 50% of the feature values are missing. For those samples, filling the missing values with some replacement values is probably not a good idea.
#
# Therefore, let’s go ahead and drop samples that have more than 20% of missing values. The threshold is inspired by the information from the ‘Data Completeness’ column on the right of this figure.

# %% [markdown]
# # Menghapus Baris dengan Missing Values melebihi 20%

# %%
df.shape
# Out:
# (466285, 44)

# %%
df = df.dropna(thresh=df.shape[1] * 0.80, axis=0).reset_index(drop=True)
df.shape
# Out:
# (466256, 44)

# %%
plt.figure(figsize=(10, 8))
plt.imshow(df.isna(), aspect="auto", interpolation="nearest", cmap="gray")
plt.xlabel("Column Number")
plt.ylabel("Sample Number");

# %% [markdown]
# # Check for Missing Values per Feature

# %%
df.isna().mean().sort_values().plot(
    kind="bar", figsize=(15, 4),
    title="Percentage of missing values per feature",
    ylabel="Ratio of missing values per feature");

# %% [markdown]
# So let’s go ahead and remove any feature with more than 15% of missing values.
#
# df_X = df_X.dropna(thresh=df_X.shape[0] * 0.85, axis=1)
# df_X.shape

# %% [markdown]
# # Menghapus Fitur dengan Missing Values melebihi 20%

# %% [markdown]
# dikarenakan dataset yang digunakan cukup besar (466285 baris) maka threshold atau batas maksimal dari missing features terhadap suatu fitur diset sebesar 20%, apabila sebuah fitur memiliki missing values lebih besar dari 20 persen artinya ada 93257 baris dengan missing value pada fitur tersebut

# %%
df.shape
# Out:
# (466256, 44)

# %%
df = df.dropna(thresh=df.shape[0] * 0.8, axis=1)
df.shape
# Out:
# (466256, 41)

# %%
df.isna().mean().sort_values().plot(
    kind="bar", figsize=(15, 4),
    title="Percentage of missing values per feature",
    ylabel="Ratio of missing values per feature");

# %% [markdown]
# # Ganti Nilai null pada Kolom Tipe Numerik Menjadi nilai rata-rata pada kolom tersebut

# %%
numerical_columns = (df.select_dtypes(include="number").columns).tolist()

# %%
# df.loc[(df[col].dtype == 'int64') | (df[col].dtype == 'float64')].isnull().sum()

# %%
num_of_null = pd.DataFrame(df[numerical_columns].isnull().sum())
num_of_null.columns = ['Number of null values per features']
num_of_null
# Out:
#                             Number of null values per features
# loan_amnt                                                    0
# funded_amnt                                                  0
# funded_amnt_inv                                              0
# int_rate                                                     0
# installment                                                  0
# annual_inc                                                   0
# dti                                                          0
# delinq_2yrs                                                  0
# inq_last_6mths                                               0
# open_acc                                                     0
# pub_rec                                                      0
# revol_bal                                                    0
# revol_util                                                 311
# total_acc                                                    0
# ...

# %%
for col in numerical_columns:
    df[col].fillna(df[col].mean(), inplace=True)

# %%
num_of_null = pd.DataFrame(df[numerical_columns].isnull().sum())
num_of_null.columns = ['Number of null values per features']
num_of_null
# Out:
#                             Number of null values per features
# loan_amnt                                                    0
# funded_amnt                                                  0
# funded_amnt_inv                                              0
# int_rate                                                     0
# installment                                                  0
# annual_inc                                                   0
# dti                                                          0
# delinq_2yrs                                                  0
# inq_last_6mths                                               0
# open_acc                                                     0
# pub_rec                                                      0
# revol_bal                                                    0
# revol_util                                                   0
# total_acc                                                    0
# ...

# %% [markdown]
# Nilai null pada kolom-kolom bertipe numerik berhasil dihilangkan

# %% [markdown]
# # Cek Nilai null pada Kolom Tipe Kategorikal

# %%
categorical_columns = (df.select_dtypes(include="object").columns).tolist()

# %%
num_of_null = pd.DataFrame(df[categorical_columns].isnull().sum())
num_of_null.columns = ['Number of null values per features']
num_of_null
# Out:
#                             Number of null values per features
# loan_amnt                                                    0
# funded_amnt                                                  0
# funded_amnt_inv                                              0
# int_rate                                                     0
# installment                                                  0
# annual_inc                                                   0
# dti                                                          0
# delinq_2yrs                                                  0
# inq_last_6mths                                               0
# open_acc                                                     0
# pub_rec                                                      0
# revol_bal                                                    0
# revol_util                                                   0
# total_acc                                                    0
# ...

# %%
df['emp_length'].unique()
# Out:
# array(['10+ years', '< 1 year', '1 year', '3 years', '8 years', '9 years',
#        '4 years', '5 years', '6 years', '2 years', '7 years', nan],
#       dtype=object)

# %% [markdown]
# # Ubah Nilai null pada Kolom 'emp_length' Menjadi 'unknown'

# %%
df['emp_length'].fillna('unknown', inplace=True)

# %%
df['emp_length'].unique()
# Out:
# array(['10+ years', '< 1 year', '1 year', '3 years', '8 years', '9 years',
#        '4 years', '5 years', '6 years', '2 years', '7 years', 'unknown'],
#       dtype=object)

# %%
categorical_columns = df.select_dtypes(include="object").columns
for col in categorical_columns:
    print(f'{col} : {df[col].isnull().sum()}')
# Out:
# grade : 0
# emp_length : 0
# home_ownership : 0
# verification_status : 0
# loan_status : 0
# pymnt_plan : 0
# purpose : 0
# initial_list_status : 0

# %% [markdown]
# # Cek Apakah Terdapat Duplicate Rows atau tidak

# %% [markdown]
# Duplicates are entries that represent the same sample point multiple times. For example, if a measurement was registered twice by two different people. Detecting such duplicates is not always easy, as each dataset might have a unique identifier (e.g. an index number or recording time that is unique to each new sample) which you might want to ignore first.

# %%
df.shape
# Out:
# (466256, 41)

# %%
duplicate_status = df.duplicated()
duplicate_status.value_counts()
# Out:
# False    466256
# dtype: int64

# %% [markdown]
# Berdasarkan pengecekan yang telah dilakukan pada code cell diatas, diperoleh nilai False senilai 466285 yang jumlahnya sama dengan jumlah baris pada dataset yang artinya pada dataset ini tidak terdapat data atau baris yang duplikat

# %% [markdown]
# # Mengecek apakah masih terdapat baris yang mengandung nilai null

# %%
# Using isna() to select all rows with NaN under an entire DataFrame:
df[df.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [loan_amnt, funded_amnt, funded_amnt_inv, int_rate, installment, grade, emp_length, home_ownership, annual_inc, verification_status, loan_status, pymnt_plan, purpose, dti, delinq_2yrs, inq_last_6mths, open_acc, pub_rec, revol_bal, revol_util, total_acc, initial_list_status, out_prncp, out_prncp_inv, total_pymnt, total_pymnt_inv, total_rec_prncp, total_rec_int, total_rec_late_fee, recoveries, collection_recovery_fee, last_pymnt_amnt, collections_12_mths_ex_med, acc_now_delinq, tot_coll_amt, tot_cur_bal, total_rev_hi_lim, bad_loan, earliest_cr_line_month, last_pymnt_d_month, term_int]
# Index: []

# %%
# Using isnull() to select all rows with NaN under an entire DataFrame:
df[df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [loan_amnt, funded_amnt, funded_amnt_inv, int_rate, installment, grade, emp_length, home_ownership, annual_inc, verification_status, loan_status, pymnt_plan, purpose, dti, delinq_2yrs, inq_last_6mths, open_acc, pub_rec, revol_bal, revol_util, total_acc, initial_list_status, out_prncp, out_prncp_inv, total_pymnt, total_pymnt_inv, total_rec_prncp, total_rec_int, total_rec_late_fee, recoveries, collection_recovery_fee, last_pymnt_amnt, collections_12_mths_ex_med, acc_now_delinq, tot_coll_amt, tot_cur_bal, total_rev_hi_lim, bad_loan, earliest_cr_line_month, last_pymnt_d_month, term_int]
# Index: []

# %%
# You may use the isna() approach to select the NaNs:

df[df.isna()]

# %% [markdown]
# sudah tidak terdapat baris dengan nilai null

# %% [markdown]
# # Meng-handle Outliers pada Kolom Numerik

# %%
df.columns
# Out:
# Index(['loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'int_rate',
#        'installment', 'grade', 'emp_length', 'home_ownership', 'annual_inc',
#        'verification_status', 'loan_status', 'pymnt_plan', 'purpose', 'dti',
#        'delinq_2yrs', 'inq_last_6mths', 'open_acc', 'pub_rec', 'revol_bal',
#        'revol_util', 'total_acc', 'initial_list_status', 'out_prncp',
#        'out_prncp_inv', 'total_pymnt', 'total_pymnt_inv', 'total_rec_prncp',
#        'total_rec_int', 'total_rec_late_fee', 'recoveries',
#        'collection_recovery_fee', 'last_pymnt_amnt',
#        'collections_12_mths_ex_med', 'acc_now_delinq', 'tot_coll_amt',
#        'tot_cur_bal', 'total_rev_hi_lim', 'bad_loan', 'earliest_cr_line_month',
#        'last_pymnt_d_month', 'term_int'],
#       dtype='object')

# %%
df.head(5)
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv  int_rate  installment grade  \
# 0       5000         5000           4975.0     10.65       162.87     B
# 1       2500         2500           2500.0     15.27        59.83     C
# 2       2400         2400           2400.0     15.96        84.33     C
# 3      10000        10000          10000.0     13.49       339.31     C
# 4       3000         3000           3000.0     12.69        67.79     B
#
#   emp_length home_ownership  annual_inc verification_status  loan_status  \
# 0  10+ years           RENT     24000.0            Verified   Fully Paid
# 1   < 1 year           RENT     30000.0     Source Verified  Charged Off
# 2  10+ years           RENT     12252.0        Not Verified   Fully Paid
# 3  10+ years           RENT     49200.0     Source Verified   Fully Paid
# 4     1 year           RENT     80000.0     Source Verified      Current
#
#   pymnt_plan         purpose    dti  delinq_2yrs  inq_last_6mths  open_acc  \
# ...

# %%
df['grade']
# Out:
# 0         B
# 1         C
# 2         C
# 3         C
# 4         B
#          ..
# 466251    C
# 466252    D
# 466253    D
# 466254    A
# 466255    D
# Name: grade, Length: 466256, dtype: object

# %% [markdown]
# # Cheking the Skewness of Numerical Columns

# %%
numerical_columns = (df.select_dtypes(include="number").columns).tolist()

# %%
from scipy.stats import skew

skewness_values = {}

for index, col in enumerate(numerical_columns):
    skewness_value = skew(df[col])
    
    print('--------------------------------------------------------')
    print(f'{index+1}. {col}')
    print(skewness_value)
    
    skewness_values[col] = skewness_value
    
    plt.figure()
    sns.displot(df[col])
    plt.show()
# Out:
# --------------------------------------------------------
# 1. loan_amnt
# 0.730974572591864
# --------------------------------------------------------
# 2. funded_amnt
# 0.7348414633451077
# --------------------------------------------------------
# 3. funded_amnt_inv
# 0.7303725371716535
# --------------------------------------------------------
# 4. int_rate
# 0.3348638355639934
# --------------------------------------------------------
# 5. installment
# 0.9493226607094102
# --------------------------------------------------------
# 6. annual_inc
# 29.571145022127496
# --------------------------------------------------------
# 7. dti
# 0.18826480648272403
# --------------------------------------------------------
# 8. delinq_2yrs
# 5.34573072192714
# --------------------------------------------------------
# 9. inq_last_6mths
# 2.1421364843727946
# --------------------------------------------------------
# 10. open_acc
# 1.1656944151642623
# ...

# %%
skewness_values_df = pd.DataFrame(skewness_values)
skewness_values_df.columns = ['skewness value']
skewness_values_df

# %%
highly_skewed = [i for i in skewness_values if (skewness_values[i] > 0.2) and (skewness_values[i] < -0.2)]

# %%
highly_skewed_values = {}
transformed = {}

for index, col in enumerate(highly_skewed):
    
    highly_skewed_values[col] = skewness_values[col]
    
    df[col+'_transformed'] = np.sqrt(df[col])
    
    transformed[col] = skew(df[col])

# %%
transformed_df = pd.DataFrame([highly_skewed_values, transformed])
transformed_df.columns =  ['before transformation','after transformation']
transformed_df

# %% [markdown]
# selanjutnya kita akan menghapus kolom-kolom dengan tingkat skewness tinggi dan menyisakan hanya kolom-kolom hasil transformasinya saja

# %%
df.shape

# %%
df.drop(highly_skewed, axis=1, inplace=True)
df.shape

# %%
df.select_dtypes(include="number").corr()
# Out:
#                             loan_amnt  funded_amnt  funded_amnt_inv  int_rate  \
# loan_amnt                    1.000000     0.998547         0.994353  0.167118
# funded_amnt                  0.998547     1.000000         0.996131  0.167856
# funded_amnt_inv              0.994353     0.996131         1.000000  0.169272
# int_rate                     0.167118     0.167856         0.169272  1.000000
# installment                  0.949660     0.951782         0.947386  0.148723
# annual_inc                   0.370918     0.370336         0.367842 -0.046070
# dti                          0.057230     0.058584         0.062496  0.159586
# delinq_2yrs                  0.006841     0.007386         0.008143  0.079190
# inq_last_6mths              -0.020328    -0.020970        -0.027580  0.205641
# open_acc                     0.204182     0.204983         0.205807  0.012307
# pub_rec                     -0.081137    -0.080593        -0.078894  0.066695
# ...

# %%
sns.heatmap(df.select_dtypes(include="number").corr())
plt.show()

# %% [markdown]
# most of the time, we handle skewness using either square root approach or log approach

# %% [markdown]
# if we transform columns wiht high skewness, then we would also remove its correalation with the target column. So, we should only transform columns that have no great correlation with target column

# %%
df['installment_transformed'] = np.sqrt(df['installment'])

# %%
skew(df['installment'])
# Out:
# 0.9493226607094102

# %%
skew(df['installment_transformed'])
# Out:
# 0.22602001770288865

# %%
df['installment_transformed_log'] = np.log(df['installment'])

# %%
skew(df['installment_transformed_log'])
# Out:
# -0.68255548908989

# %% [markdown]
# we're succesfully reduce the skewness value of column 'installment' to only 0.2

# %% [markdown]
# we should not be applying sqrt transformation on columns that have negative values, otherwise it will produce null values since we can't perform sqrt operation on null value

# %%
np.sqrt(-1)
# Out:
# C:\Users\Sandie\AppData\Local\Temp\ipykernel_9164\3438155168.py:1: RuntimeWarning: invalid value encountered in sqrt
#   np.sqrt(-1)
# nan

# %%
np.log(-1)
# Out:
# C:\Users\Sandie\AppData\Local\Temp\ipykernel_9164\153577755.py:1: RuntimeWarning: invalid value encountered in log
#   np.log(-1)
# nan

# %%
# Here is an approach to remove variables with a correlation coef value below some threshold:
import pandas as pd
from scipy.stats import spearmanr

data = pd.DataFrame([{"A":1, "B":2, "C":3},{"A":2, "B":3, "C":1},{"A":3, "B":4, "C":0},{"A":4, "B":4, "C":1},{"A":5, "B":6, "C":2}])
targetVar = "A"
corr_threshold = 0.4

corr = spearmanr(data)
corrSeries = pd.Series(corr[0][:,0], index=data.columns) #Series with column names and their correlation coefficients
corrSeries = corrSeries[(corrSeries.index != targetVar) & (corrSeries > corr_threshold)] #apply the threshold

vars_to_keep = list(corrSeries.index.values) #list of variables to keep
vars_to_keep.append(targetVar)  #add the target variable back in
data2 = data[vars_to_keep]

# %%
to_drop = [column for column in upper_tri.columns if any(upper_tri[column] > 0.95)]
    print(); print(to_drop)

# %% [markdown]
# # Exploratory Data Analysis

# %%
len(categorical_columns)
# Out:
# 9

# %%
# categorical columns
categorical_columns = [col for col in df.columns if df[col].dtype == object]
for index, feature in enumerate(categorical_columns):
    # feature = categorical_features[0]
    count = df[feature].value_counts()
    percent = 100*df[feature].value_counts(normalize=True)
    new_df = pd.DataFrame({'jumlah sampel':count, 'persentase':percent.round(1)})
    print('--------------------------------------------------------')
    print(f'{index+1}. {feature}')
    print(new_df)
    plt.figure()
    count.plot(kind='bar', title=feature);
    plt.show()
# Out:
# --------------------------------------------------------
# 1. grade
#    jumlah sampel  persentase
# B         136919        29.4
# C         125287        26.9
# D          76887        16.5
# A          74856        16.1
# E          35756         7.7
# F          13229         2.8
# G           3322         0.7
# --------------------------------------------------------
# 2. emp_length
#            jumlah sampel  persentase
# 10+ years         150046        32.2
# 2 years            41372         8.9
# 3 years            36594         7.8
# < 1 year           36247         7.8
# 5 years            30774         6.6
# 1 year             29619         6.4
# 4 years            28023         6.0
# 7 years            26180         5.6
# 6 years            26111         5.6
# 8 years            22395         4.8
# unknown            21008         4.5
# 9 years            17887         3.8
# --------------------------------------------------------
# 3. home_ownership
# ...

# %%
# menampilkan histogram untuk data numerik
# df.hist(bins=50, figsize=(20,15))
# plt.show()

# %% [markdown]
# berdasarkan histogram diatas, terlihat bahwa sebagian besar kolom (fitur) memiliki beberapa nilai dengan frekuensi atau kemunculan yang sangat tinggi. Oleh karena itu, kita akan mengecek berapa persentase kemunculan nilai-nilai tersebut dibanding nilai-nilai yang lain

# %%
# columns_without_most_frequent_entry = [
#     'loan_amnt','funded_amnt','funded_amnt_inv','int_rate','installment','dti','open_acc',
#     'revol_util','total_acc','total_pymnt','total_pymnt_inv','total_rec_prncp','total_rec_int'
# ]

# %%
# columns_with_most_frequent_entry = [
#     'annual_inc', 
#     'delinq_2yrs', 'inq_last_6mths', 'mths_since_last_delinq', 'mths_since_last_record',
#     'pub_rec', 'revol_bal', 'out_prncp', 'out_prncp_inv',
#     'total_rec_late_fee', 'recoveries',
#     'collection_recovery_fee', 'last_pymnt_amnt', 'collections_12_mths_ex_med', 
#     'mths_since_last_major_derog', 'policy_code', 'acc_now_delinq',
#     'tot_coll_amt', 'tot_cur_bal', 'total_rev_hi_lim' 
    
# ]

# %%
# numerical_columns = [
#     col for col in df.columns 
#     if df[col].dtype == 'int64' or df[col].dtype == 'float64'
# ]

# columns_with_most_frequent_entry = [ 
#     x for x in numerical_columns if x not in columns_without_most_frequent_entry
# ]

# columns_with_most_frequent_entry

# %%
# for index, col in enumerate(columns_with_most_frequent_entry):
#     print(f'{index+1}. {col}')
    
#     count = list(df[col].value_counts())
#     percent = list(df[col].value_counts(normalize=True) * 100)
    
#     dict = {'jumlah sampel':count, 'persentase':percent}
# #     sorted_dict = sorted(dict.items(), key=lambda x: x[1])
    
#     new_df = pd.DataFrame(dict)
    
#     print(new_df)
    
#     print(f'number of unique values : {df[col].nunique()}')
    
#     print('--------------------------------------------------')

# %%
# df['mths_since_last_delinq'].value_counts(normalize=True)*100

# %%
# df.head()

# %%
# df.columns

# %%
# # visualisasikan data dengan boxplot untuk mendeteksi outliers 
# # pada beberapa fitur numerik
# numerical_columns = [
#     col for col in df.columns 
#     if df[col].dtype == 'int64' or df[col].dtype == 'float64'
# ]

# for feature in numerical_columns:
#     sns.boxplot(x=df[feature])

# %%
# # drop outliers menggunakan metode IQR
# Q1 = df.quantile(0.25)
# Q3 = df.quantile(0.75)
# IQR=Q3-Q1
# df=df[~((df<(Q1-1.5*IQR))|(df>(Q3+1.5*IQR))).any(axis=1)]
 
# # Cek ukuran dataset setelah kita drop outliers
# diamonds.shape

# %%
# #multivariate eda
 
# for col in categorical_columns:
#   sns.catplot(x=col, y="bad_loan", kind="bar", dodge=False, height = 4, aspect = 3,  data=df, palette="Set3")
#   plt.title("Rata-rata 'bad_loan' Relatif terhadap - {}".format(col))

# %%
# # Mengamati hubungan antar fitur numerik dengan fungsi pairplot()
# sns.pairplot(df, diag_kind = 'kde')

# %%
# plt.figure(figsize=(10, 8))
# correlation_matrix = df.corr().round(2)
 
# # Untuk menge-print nilai di dalam kotak, gunakan parameter anot=True
# sns.heatmap(data=correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5, )
# plt.title("Correlation Matrix untuk Fitur Numerik ", size=20)

# %% [markdown]
# # EDA Menggunakan Pandas Profiling

# %%
# from pandas_profiling import ProfileReport

# %%
# variables = {
#     "descriptions":{
#         "id" : "ID yang ditugaskan LC yang unik untuk daftar pinjaman.",
#         "member_id" : "ID yang ditugaskan LC yang unik untuk anggota peminjam.",
#         "loan_amnt" : "Jumlah pinjaman yang terdaftar yang diterapkan oleh peminjam. Jika pada suatu titik waktu, departemen kredit mengurangi jumlah pinjaman, maka itu akan tercermin dalam nilai ini.",
#         "funded_amnt" : "Jumlah total yang berkomitmen untuk pinjaman itu pada saat itu.",
#         "funded_amnt_inv" : "Jumlah total yang dilakukan oleh investor untuk pinjaman itu pada saat itu.",
#         "term" : "Jumlah pembayaran pinjaman. Nilai dalam beberapa bulan dan dapat berupa 36 atau 60.",
#         "int_rate" : "Suku bunga pinjaman",
#         "installment" : "Pembayaran bulanan yang terutang oleh peminjam jika pinjaman berasal.",
#         "grade" : "LC menugaskan nilai pinjaman",
#         "sub_grade" : "LC Ditugaskan Subgrade Pinjaman",
#         "emp_title" : "Judul pekerjaan yang disediakan oleh peminjam saat mengajukan pinjaman.",
# * **emp_length**	- Panjang pekerjaan dalam beberapa tahun. Nilai yang mungkin adalah antara 0 dan 10 di mana 0 berarti kurang dari satu tahun dan 10 berarti sepuluh tahun atau lebih.
# * **home_ownership**	- Status kepemilikan rumah yang disediakan oleh peminjam selama pendaftaran. Nilai -nilai kami adalah: sewa, sendiri, hipotek, lainnya.
# * **annual_inc**	- Penghasilan tahunan yang dilaporkan sendiri yang disediakan oleh peminjam selama pendaftaran.
# * **verification_status** - --------------------------------------------------------------
# * **issue_d**	- Bulan yang didanai pinjaman
# * **pymnt_plan**	- Menunjukkan jika rencana pembayaran telah diberlakukan untuk pinjaman
# * **url** - URL untuk halaman LC dengan data daftar.
# * **desc** - Deskripsi pinjaman yang disediakan oleh peminjam
# * **purpose**	- Kategori yang disediakan oleh peminjam untuk permintaan pinjaman.
# * **title** - Judul pinjaman yang disediakan oleh peminjam
# * **zip_code** - 3 nomor pertama dari kode pos yang disediakan oleh peminjam dalam aplikasi pinjaman.
# * **addr_state**	- Negara yang disediakan oleh peminjam dalam aplikasi pinjaman
# * **dti**	- Rasio yang dihitung menggunakan total pembayaran utang bulanan peminjam atas total kewajiban utang, tidak termasuk hipotek dan pinjaman LC yang diminta, dibagi dengan pendapatan bulanan peminjam yang dilaporkan sendiri.
# * **delinq_2yrs** - Jumlah 30+ hari insiden kenakalan yang lewat dalam file kredit peminjam selama 2 tahun terakhir
# * **earliest_cr_line** - Bulan jalur kredit yang paling awal dilaporkan peminjam dibuka
# * **inq_last_6mths** - Jumlah pertanyaan dalam 6 bulan terakhir (tidak termasuk pertanyaan otomatis dan hipotek)
# * **mths_since_last_delinq** - Jumlah bulan sejak kenakalan terakhir peminjam.
# * **mths_since_last_record** - Jumlah bulan sejak catatan publik terakhir.
# * **open_acc** - Jumlah jalur kredit terbuka dalam file kredit peminjam.
# * **pub_rec** - Jumlah catatan publik yang menghina
# * **revol_bal** - Total Saldo Revolving Credit
# * **revol_util** - Tingkat pemanfaatan jalur bergulir, atau jumlah kredit yang digunakan peminjam relatif terhadap semua kredit revolving yang tersedia.
# * **total_acc** - Jumlah total jalur kredit saat ini dalam file kredit peminjam
# * **initial_list_status** - Status daftar awal pinjaman. Nilai yang mungkin adalah - w, f
# * **out_prncp** - Kepala sekolah yang tersisa untuk jumlah total yang didanai
# * **out_prncp_inv** - Kepala sekolah yang tersisa untuk sebagian dari jumlah total yang didanai oleh investor
# * **total_pymnt** - Pembayaran diterima hingga saat ini untuk jumlah total yang didanai
# * **total_pymnt_inv** - Pembayaran diterima hingga saat ini untuk sebagian dari jumlah total yang didanai oleh investor
# * **total_rec_int** - Bunga diterima hingga saat ini
# * **total_rec_late_fee** - Biaya keterlambatan yang diterima hingga saat ini
# * **total_rec_prncp** - Kepala sekolah diterima hingga saat ini
# * **recoveries** - Posting biaya pemulihan kotor
# * **collection_recovery_fee** - Biaya pengumpulan biaya penagihan
# * **last_pymnt_d** - Bulan lalu pembayaran diterima
# * **last_pymnt_amnt** - Jumlah total pembayaran terakhir yang diterima
# * **next_pymnt_d** - Tanggal Pembayaran Terjadwal Berikutnya
# * **last_credit_pull_d** - Bulan terbaru LC menarik kredit untuk pinjaman ini
# * **collections_12_mths_ex_med** - Jumlah koleksi dalam 12 bulan tidak termasuk koleksi medis
# * **mths_since_last_major_derog** - Bulan sejak peringkat 90 hari atau lebih buruk terakhir
# * **policy_code**	 - "Policy_code yang tersedia untuk umum = 1 Produk Baru Tidak Tersedia Umum Kebijakan_Code = 2"
# * **application_type** - Menunjukkan apakah pinjaman adalah aplikasi individu atau aplikasi bersama dengan dua peminjam bersama
# * **annual_inc_joint** - Penghasilan tahunan yang dilaporkan sendiri gabungan yang disediakan oleh co-peminjam selama pendaftaran
# * **dti_joint** - Rasio yang dihitung menggunakan total pembayaran bulanan peminjam bersama atas total kewajiban utang, tidak termasuk hipotek dan pinjaman LC yang diminta, dibagi oleh pendapatan bulanan yang dilaporkan sendiri oleh co-peminjam yang dilaporkan sendiri
# * **verification_status_joint** - ------------------------------------------------------------------------
# * **acc_now_delinq** - Jumlah akun di mana peminjam sekarang nakal.
# * **tot_coll_amt** - Total jumlah pengumpulan yang pernah ada
# * **tot_cur_bal** - Total Saldo Saat Ini dari Semua Akun
# * **open_acc_6m** - Jumlah perdagangan terbuka dalam 6 bulan terakhir
# * **open_il_6m** - Jumlah perdagangan angsuran aktif saat ini
# * **open_il_12m** - Jumlah akun angsuran yang dibuka dalam 12 bulan terakhir
# * **open_il_24m** - Jumlah akun angsuran yang dibuka dalam 24 bulan terakhir
# * **mths_since_rcnt_il** - Bulan sejak akun angsuran terbaru dibuka
# * **total_bal_il** - Total saldo saat ini dari semua akun angsuran
# * **il_util** - Rasio total saldo saat ini dengan batas kredit/kredit tinggi pada semua instal acct
# * **open_rv_12m** - Jumlah perdagangan revolving dibuka dalam 12 bulan terakhir
# * **open_rv_24m** - Jumlah perdagangan revolving dibuka dalam 24 bulan terakhir
# * **max_bal_bc** - Saldo arus maksimum terutang pada semua akun bergulir
# * **all_util** - Saldo ke batas kredit untuk semua perdagangan
# * **total_rev_hi_lim** - Total Batas Kredit/Kredit Tinggi Revolving
# * **inq_fi** - Jumlah pertanyaan keuangan pribadi
# * **total_cu_tl** - Jumlah Perdagangan Keuangan
# * **inq_last_12m** - Jumlah pertanyaan kredit dalam 12 bulan terakhir
# * **bad_loan** - data orang tepat membayar full atau tidak
#     }
# }

# %%
# dataset = {
#     "description": "This profiling report was generated using pandas profiling",
#     "copyright_holder": "Rizkyka Mediano Sandie",
#     "copyright_year": "2022",
#     "url": "https://www.masihbelumpunya.com",
# }

# %%
# profile = ProfileReport(
#     df, 
#     title="Random Data",
#     dataset=dataset
# #     variables=variables,
# )
# profile

# %% [markdown]
# # Menyimpan Hasil Visualisasi sebagai File HMTL

# %%
# profile.to_file("my_report.html")

# %% [markdown]
# # Cek Jumlah Unique Values pada Kolom Kategorikal

# %%
# for col in categorical_columns:
#     print(f'{col} : {df[col].nunique()}')

# %% [markdown]
# # One-Hot Encode Kolom Kategorikal

# %%
df.shape
# Out:
# (466256, 41)

# %%
# for col in categorical_columns:
#     df = pd.concat([df, pd.get_dummies(df[col], prefix=col)], axis='columns')
# df.drop(categorical_columns, axis='columns', inplace=True)
# df.head()

# %%
df.shape
# Out:
# (466256, 41)

# %% [markdown]
# # Data Cleaning and Prepocessing

# %%
df.columns
# Out:
# Index(['loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'int_rate',
#        'installment', 'grade', 'emp_length', 'home_ownership', 'annual_inc',
#        'verification_status', 'loan_status', 'pymnt_plan', 'purpose', 'dti',
#        'delinq_2yrs', 'inq_last_6mths', 'open_acc', 'pub_rec', 'revol_bal',
#        'revol_util', 'total_acc', 'initial_list_status', 'out_prncp',
#        'out_prncp_inv', 'total_pymnt', 'total_pymnt_inv', 'total_rec_prncp',
#        'total_rec_int', 'total_rec_late_fee', 'recoveries',
#        'collection_recovery_fee', 'last_pymnt_amnt',
#        'collections_12_mths_ex_med', 'acc_now_delinq', 'tot_coll_amt',
#        'tot_cur_bal', 'total_rev_hi_lim', 'bad_loan', 'earliest_cr_line_month',
#        'last_pymnt_d_month', 'term_int'],
#       dtype='object')

# %%
df['tot_cur_bal'][0]
# Out:
# 0.0

# %%
df['tot_cur_bal'][0].dtype
# Out:
# dtype('float64')

# %% [markdown]
# # Train Test Split

# %%
# from sklearn.model_selection import train_test_split
 
# X = df.drop(["bad_loan"], axis='columns')
# y = df["bad_loan"]
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1, random_state = 123)

# %% [markdown]
# # Standarisasi

# %% [markdown]
# Algoritma machine learning memiliki performa lebih baik dan konvergen lebih cepat ketika dimodelkan pada data dengan skala relatif sama atau mendekati distribusi normal. Proses scaling dan standarisasi membantu untuk membuat fitur data menjadi bentuk yang lebih mudah diolah oleh algoritma.
#
# Standardisasi adalah teknik transformasi yang paling umum digunakan dalam tahap persiapan pemodelan. Untuk fitur numerik, kita tidak akan melakukan transformasi dengan one-hot-encoding seperti pada fitur kategori. Kita akan menggunakan teknik StandarScaler dari library Scikitlearn,
#
# StandardScaler melakukan proses standarisasi fitur dengan mengurangkan mean (nilai rata-rata) kemudian membaginya dengan standar deviasi untuk menggeser distribusi. StandardScaler menghasilkan distribusi dengan standar deviasi sama dengan 1 dan mean sama dengan 0. Sekitar 68% dari nilai akan berada di antara -1 dan 1.
#
# Untuk menghindari kebocoran informasi pada data uji, kita hanya akan menerapkan fitur standarisasi pada data latih. Kemudian, pada tahap evaluasi, kita akan melakukan standarisasi pada data uji. Untuk lebih jelasnya, mari kita terapkan StandardScaler pada data.

# %%
# from sklearn.preprocessing import StandardScaler
 
# numerical_columns = [
#     col for col in df.columns 
#     if df[col].dtype == 'int64' or df[col].dtype == 'float64'
# ]
    
# scaler = StandardScaler()
# scaler.fit(X_train[numerical_columns])
# X_train[numerical_columns] = scaler.transform(X_train.loc[:, numerical_columns])
# X_train[numerical_columns].head()

# %% [markdown]
# # Modelling

# %%
# # Siapkan dataframe untuk analisis model
# models = pd.DataFrame(index=['train_mse', 'test_mse'], 
#                       columns=['KNN', 'RandomForest', 'Boosting'])

# %%
# #latih data dengan KNN

# from sklearn.neighbors import KNeighborsRegressor
# from sklearn.metrics import mean_squared_error
 
# knn = KNeighborsRegressor(n_neighbors=10)
# knn.fit(X_train, y_train)
 
# models.loc['train_mse','knn'] = mean_squared_error(y_pred = knn.predict(X_train), y_true=y_train)

# %%
# # Impor library yang dibutuhkan
# from sklearn.ensemble import RandomForestRegressor
 
# # buat model prediksi
# RF = RandomForestRegressor(n_estimators=50, max_depth=16, random_state=55, n_jobs=-1)
# RF.fit(X_train, y_train)
 
# models.loc['train_mse','RandomForest'] = mean_squared_error(y_pred=RF.predict(X_train), y_true=y_train)

# %%
# from sklearn.ensemble import AdaBoostRegressor
 
# boosting = AdaBoostRegressor(learning_rate=0.05, random_state=55)                             
# boosting.fit(X_train, y_train)
# models.loc['train_mse','Boosting'] = mean_squared_error(y_pred=boosting.predict(X_train), y_true=y_train)

# %% [markdown]
# # Evaluasi Model

# %%
# # Buat variabel mse yang isinya adalah dataframe nilai mse data train dan test pada masing-masing algoritma
# mse = pd.DataFrame(columns=['train', 'test'], index=['KNN','RF','Boosting'])
 
# # Buat dictionary untuk setiap algoritma yang digunakan
# model_dict = {'KNN': knn, 'RF': RF, 'Boosting': boosting}
 
# # Hitung Mean Squared Error masing-masing algoritma pada data train dan test
# for name, model in model_dict.items():
#     mse.loc[name, 'train'] = mean_squared_error(y_true=y_train, y_pred=model.predict(X_train))/1e3 
#     mse.loc[name, 'test'] = mean_squared_error(y_true=y_test, y_pred=model.predict(X_test))/1e3
 
# # Panggil mse
# mse

# %%
# fig, ax = plt.subplots()
# mse.sort_values(by='test', ascending=False).plot(kind='barh', ax=ax, zorder=3)
# ax.grid(zorder=0)

# %% [markdown]
# # Deep Learning

# %%
# import tensorflow as tf

# %%
# model = tf.keras.models.Sequential([

#     tf.keras.layers.Dense(128, activation='relu' , input_shape=(88,)),
#     tf.keras.layers.Dropout(0.3),
#     tf.keras.layers.Dense(32, activation='relu'),
#     tf.keras.layers.Dropout(0.3),
#     tf.keras.layers.Dense(1, activation='sigmoid')  
# ])

# %%
# model.summary()

# %%
# model.compile(loss='binary_crossentropy',
#               optimizer=tf.optimizers.Adam(learning_rate=0.001),
#               metrics=['accuracy'])

# %%
# # define callbacks
# class myCallback(tf.keras.callbacks.Callback):
#     def on_epoch_end(self, epoch, logs={}):
#         accuracy = logs.get('accuracy')
#         val_accuracy = logs.get('val_accuracy')
#         desired_acc = 0.96
#         if (val_accuracy > desired_acc) and (accuracy > desired_acc):
#             self.model.stop_training = True
#             print('desired accuracy reached')

# custom_early_stopping = tf.keras.callbacks.EarlyStopping(
#     monitor='val_loss',
#     patience=5,
#     min_delta=0.001,
#     mode='min',
#     restore_best_weights=True,
#     verbose=1
# )

# %%
# model.fit(
#       X_train, y_train,
#       epochs=5, 
#       validation_data=(X_test, y_test), 
#       callbacks=[custom_early_stopping]
#       )
